# %%
#Imports
import numpy as np
from scipy import signal
from scipy import misc
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
from PIL import Image

# %%
img_ponto = Image.open('images/3_1_05_02_2019_08_27.jpg').convert('L')

# %%
img_ponto
# Out:
# <PIL.Image.Image image mode=L size=2150x1692 at 0x1BEE6515F28>

# %%
#img_ponto = img_ponto.convert("L")    # convert("L") translate color images into black and white
                              # uses the ITU-R 601-2 Luma transform (there are several 
                              # ways to convert an image to grey scale)
img_ponto
# Out:
# <PIL.Image.Image image mode=L size=2150x1692 at 0x1BEE6515F28>

# %%
# convert image to a matrix with values from 0 to 255 (uint8) 
np_ponto = np.asarray(img_ponto)
np_ponto2 = np.array(np_ponto[380:510,40:100])



np_ponto2
# Out:
# array([[109, 113, 117, ..., 124, 126, 127],
#        [110, 113, 118, ..., 124, 125, 125],
#        [111, 115, 120, ..., 126, 126, 126],
#        ...,
#        [117, 119, 119, ..., 119, 118, 118],
#        [118, 120, 120, ..., 120, 119, 118],
#        [118, 120, 120, ..., 120, 119, 119]], dtype=uint8)

# %%
### Plot image
# %matplotlib inline
plt.imshow(np_ponto2)

# %%
np_ponto3 = np_ponto2


plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %%
kernel = np.array([[ 0, 1, 0],
                   [ 1, -4, 1],
                   [ 0, 1, 0],
                  ])

# %%
image_ponto_grad = signal.convolve2d(np_ponto, kernel, mode='same', boundary='symm')
np.asarray(image_ponto_grad)
# Out:
# array([[-7.84313725e-03, -1.17647059e-02,  0.00000000e+00, ...,
#          3.92156863e-03,  3.92156863e-03,  3.92156863e-03],
#        [ 3.92156863e-03,  3.92156863e-03,  0.00000000e+00, ...,
#          3.92156863e-03,  3.92156863e-03,  3.92156863e-03],
#        [ 7.84313725e-03,  7.84313725e-03,  7.84313725e-03, ...,
#         -1.56862745e-02, -1.96078431e-02, -1.96078431e-02],
#        ...,
#        [ 3.92156863e-03, -7.84313725e-03,  1.17647059e-02, ...,
#          1.11022302e-16, -7.84313725e-03, -7.84313725e-03],
#        [-3.92156863e-03, -3.92156863e-03, -3.92156863e-03, ...,
#          1.96078431e-02, -7.84313725e-03,  3.92156863e-03],
#        [ 7.84313725e-03, -7.84313725e-03,  0.00000000e+00, ...,
#          1.17647059e-02,  1.17647059e-02, -1.17647059e-02]])

# %%
plt.imshow(np.absolute(image_ponto_grad), cmap='gray')
